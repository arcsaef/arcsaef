# %%
import json
import re
from datetime import datetime

# %%
# Export item > BetterBibTex JSON
with open('data/all/BIB_saef_20141114.json', 'r') as f:
    bib = json.load(f)

# %%
# Author search experimentation
for b in bib['items']:
    if b['itemType'] == 'dataset':
        if b['date'].endswith('2024'):
            author_list = re.findall(r"saef: .*|saef:.*", b['extra'])
            print(author_list)
# Out:
# ['saef: StevenChown; CassandraBrooks']
# ['saef: JasmineLee; StevenChown']
# ['saef: JuanSandino; BarbaraBollard; KrystalRandall; JohanBarthélemy; SharonRobinson; FelipeGonzalez']
# ['saef:JuanSandino;JohanBarthélemy;KrystalRandall;SharonRobinson;FelipeGonzalez;BarbaraBollard']
# ['saef: RodolfoAnderson']

# %%
#
author_outputs = {}
for b in bib['items']:
    try:
        # CamelCaps author name prepended by "saef:" in the extra field
        saef_author_list = re.findall(r"saef: .*|saef:.*", b['extra'])
        for names in saef_author_list:
            names_tidy  = re.sub('saef:', '', names, flags=re.IGNORECASE)
            names_split = names_tidy.strip().split(';') # Create a list of saef names

            for name in names_split:
                ns = name.strip()

                if ns in author_outputs:
                    author_outputs[ns].append(b['key'])
                else:
                    author_outputs[ns] = [b['key']]
    except:
        # catch output without a saef shouldn't exist but mistakes happen
        if 'extra' in author_outputs:
            author_outputs['extra'].append(b['key'])
        else:
            author_outputs['extra'] = [b['key']]

# %%
def printDate(dt):
    dt_1 = dt.replace("/", "-")
    dt_1 = dt_1[ :10] if len(dt_1) > 10 else dt_1
    try:
        if re.match(r"\d{1,2}-\d{1,2}-\d{4}", dt_1):    # dd-mm-yyyy
            return(datetime.strptime(dt_1, "%d-%m-%Y").date().strftime("%d %B %Y"))
        elif re.match(r"\d{4}-\d{1,2}-\d{1,2}", dt_1):  # yyyy-mm-dd
            return(datetime.strptime(dt_1, "%Y-%m-%d").date().strftime("%d %B %Y"))
        elif re.match(r"\d{1,2}-\d{4}", dt_1):          # mm-yyyy
            return(datetime.strptime(dt_1, "%m-%Y").date().strftime("%B %Y"))
        elif re.match(r"\d{4}-\d{1,2}", dt_1):          # yyyy-mm
            return(datetime.strptime(dt_1, "%Y-%m").date().strftime("%B %Y"))
        else:
            return(dt_1)
    except:
        return(f"error {dt_1}")

# for b in bib['items']:
#     print(printDate(b['date']))

# %%
# Build a bibliography
bibliography = {}
for b in bib['items']:
    # publication year, yyyy
    dt = re.findall(r"\d{4}", b['date'])
    dt = "".join(dt)

    try:
        authorship = ""
        for a in b['creators']:
            authorship += f"{a['lastName']} {a['firstName']}, "
        authorship = authorship[:-2]
    except:
        authorship = "missing"
    
    try:
        doi = ", DOI:" + b['DOI'] 
    except:
        doi = ""

    try:
        url = ", " + b['url'] 
    except:
        url = ""

    if b['itemType'] == 'artwork':
        citation = f"{authorship} ({dt}) {b['title']}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'blogPost':
        citation = f"{authorship} ({dt}) {b['title']}{url}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'bookSection':
        citation = f"{authorship} ({dt}) {b['title']}{doi}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'conferencePaper':
        citation = f"{authorship} ({dt}) {b['title']}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'dataset':
        citation = f"{authorship} ({dt}) {b['title']}{doi}"
        bibliography[b['key']] = citation[:-2]
    elif b['itemType'] == 'film':
        citation = f"{authorship} ({dt}) {b['title']}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'journalArticle':
        try:
            vol = ", " + b['volume'] 
        except:
            vol = ""
        try:
            pg = ", " + b['pages'] 
        except:
            pg = ""
           
        citation = f"{authorship} ({dt}) {b['title']}, {b['publicationTitle']}{vol}{pg}{doi}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'letter':
        citation = f"{authorship} ({dt}) {b['title']}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'magazineArticle':
        citation = f"{authorship} ({dt}) {b['title']}{url}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'newspaperArticle':
        citation = f"{authorship} ({dt}) {b['title']}{url}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'presentation':
        citation = f"{authorship} ({dt}) {b['title']}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'radioBroadcast':
        radio_dt = printDate(b['date'])
        citation = f"{authorship} ({dt}) {b['title']}, {radio_dt} {url}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'tvBroadcast':
        tele_dt = printDate(b['date'])
        citation = f"{authorship} ({dt}) {b['title']}, {tele_dt} {url}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'videoRecording':
        vid_dt = printDate(b['date'])
        citation = f"{authorship} ({dt}) {b['title']}, {vid_dt} {url}"
        bibliography[b['key']] = citation
    elif b['itemType'] == 'webpage':
        citation = f"{authorship} ({dt}) {b['title']}{url}"
        bibliography[b['key']] = citation

# %%
bibliography
# Out:
# {'229BRPKA': 'Lappan Rachael, Chown Steven L., French Matthew, Perlaza-Jiménez Laura, Macesic Nenad, Davis Mark, Brown Rebekah, Cheng Allen, Clasen Thomas, Conlan Lindus, Goddard Frederick, Henry Rebekah, Knight Daniel R., Li Fuyi, Luby Stephen, Lyras Dena, Ni Gaofeng, Rice Scott A., Short Francesca, Song Jiangning, Whittaker Andrea, Leder Karin, Lithgow Trevor, Greening Chris (2024) Towards integrated cross-sectoral surveillance of pathogens and antimicrobial resistance: Needs, approaches, and considerations for linking surveillance to action, Environment International, 192, 109046, DOI:10.1016/j.envint.2024.109046',
#  '23W466NZ': 'Barthélemy Johan, Randall Krystal, Tu Melody (2024) AI Investigates Antarctica’s Disappearing Moss to Uncover Climate Change Clues, https://developer.nvidia.com/blog/ai-investigates-antarcticas-disappearing-moss-to-uncover-climate-change-clues/',
#  '25GDBSJU': "Chown Steven (2024) Living on the edge of ice: The haunting reality of top scientist Steven Chown's Antarctic odyssey",
#  '2ENFKPJS': 'Chown Steven, Bastmeijer Kees, Brooks Cassandra M, Gilbert Neil, Phillips Laura, Shibata Akiho (2024) Data and code for the paper SCAR and the Antarctic Treaty System – an evidence-based perspective, DOI:10.26180/24195345.',
#  '2NRXEWP2': 'Eaves Shaun R., Mackintosh Andrew N., Pedro Joel B., Bostock Helen C., Ryan Matthew T., Norton Kevin P., Hayward Bruce W., Anderson Brian M., He Feng, Jones Richard S., Lorrey Andrew M., Newnham Rewi M., Tims Stephen G., Vandergoes Marcus J. (2024) Coupled atmosphere-ocean response of the southwest Pacific to deglacial changes in Atlantic meridional overturning circulation, Earth and Planetary Science Letters, 641, 118802, DOI:10.1016/j.epsl.2024.118802',
#  '34CDKUSH': 'Robinson Sharon (2024) 南極夏季紫外輻射升高 專家擔憂小動物受傷害, https://aucd.com.au/australian-news/nanjixiajiziwaifusheshenggao-zhuanjiadanyouxiaodongwushoushanghai/',
#  '34H36XHH': 'McGeoch Melodie A., Clarke David A., Mungi Ninad Avinash, Ordonez Alejandro (2024) A nature-positive future with biological invasions: theory, decision support and research needs, Philosophical Transactions of the Royal Society B: Biological Sciences, 379, 20230014, DOI:10.1098/rstb.2023.0014',
#  '3BSBX5WT': 'Greening Chris (2024) What we’ve discovered about amazing microbes, https://cosmosmagazine.com/science/biology/nbt-microbes-chris-greening/',
#  '3TQF57VX': 'Jansen Marcel A. K., Andrady Anthony L., Bornman Janet F., Aucamp Pieter J., Bais Alkiviadis F., Banaszak Anastazia T., Barnes Paul W., Bernhard Germar H., Bruckman Laura S., Busquets Rosa, Häder Donat-P., Hanson Mark L., Heikkilä Anu M., Hylander Samuel, Lucas Robyn M., Mackenzie Roy, Madronich Sasha, Neale Patrick J., Neale Rachel E., Olsen Catherine M., Ossola Rachele, Pandey Krishna K., Petropavlovskikh Irina, Revell Laura E., Robinson Sharon A., Robson T. Matthew, Rose Kevin C., Solomon Keith R., Andersen Mads P. Sulbæk, Sulzberger Barbara, Wallington Timothy J., Wang Qing-Wei, Wängberg Sten-Åke, White Christopher C., Young Antony R., Zepp Richard G., Zhu Liping (2024) Plastics in the environment in the context of UV radiation, climate change and the Montreal Protocol: UNEP Environmental Effects Assessment Panel, Update 2023, Photochemical & Photobiological Sciences, 23, 629-650, DOI:10.1007/s43630-024-00552-3',
#  '3V7AH836': 'Lau Sally (2024) How an octopus told us the West Antarctic ice sheet collapsed, 13 January 2024 , https://www.cbc.ca/radio/quirks/quirks-quarks-jan-13-2024-1.7081742',
#  '47VRKKIG': 'McCormack Felicity (2024) Interview with Dr Felicity McCormack, 03 March 2024 , https://www.rrr.org.au/explore/programs/radio-marinara/episodes/28432-radio-marinara-3-march-2024',
#  '4BW8HG7P': "Chown S. L., Firth, A.  (2024) Antarctica's future is our future",
#  '4HW2YHWN': 'Lee Jasmine, Chown Steven (2024) Conservation features of the terrestrial Antarctic Peninsula Online Material, DOI:https://doi.org/10.26180/24023637.',
#  '4IE2BPRW': 'Cressie N. (2024) Spatial prediction of non-negative spatial process using asymmetric loss functions',
#  '4IGN7Q59': 'Klages J.P., Müller J, McNeil M, Lembke-Jene L, Gohl K, Esper O, Schwarzbach P, Schulze-Tenberge Y, Mackintosh A, Krastel S (2024) New Insights Into Past East Antarctic Margin Ice Sheet Behavior From Combined Geophysical and Geological Data Collected During RV Polarstern Expeditions PS140 and PS141 (EASI-2 and -3)',
#  '4VXVJLZ7': 'Jeynes‐Smith Cailan, Bode Michael, Araujo Robyn P. (2024) Identifying and explaining resilience in ecological networks, Ecology Letters, 27, e14484, DOI:10.1111/ele.14484',
#  '4XYRH4X6': 'Kirschbaum Miko U.F., Cowie Annette L., Peñuelas Josep, Smith Pete, Conant Richard T., Sage Rowan F., Brandão Miguel, Cotrufo M. Francesca, Luo Yiqi, Way Danielle A., Robinson Sharon A. (2024) Is tree planting an effective strategy for climate change mitigation?, Science of The Total Environment, 909, 168479, DOI:10.1016/j.scitotenv.2023.168479',
#  '563VRC2M': "Robinson Sharon (2024) Documental 'Un Viaje Infinito', 18 April 2024 , https://www.youtube.com/watch?v=MskHRo5LxsU&t=378s",
#  '5AUW8322': 'missing (2024) High-resolution elevation models and orthophotos of Larsen B glaciers extracted from 1960s imagery, DOI:10.17632/PFS54TFVYM',
#  '5HCTJR74': 'Zammit-Mangion A. (2024) Amortised inference in environmental applications',
#  '5RC55CWW': 'Barthelemy J, Randall K., Iqbal U., Henness D., Angus C. (2024) Unlocking secrets in extreme environments: An AIoT platform for long-term and real-time environmental monitoring in Antarctica. NVIDIA GTC',
#  '5S2GIBNI': 'Robinson Sharon (2024) Seal pups and penguin chicks exposed to more UV in Antarctica, https://www.rnz.co.nz/news/on-the-inside/515406/seal-pups-and-penguin-chicks-exposed-to-more-uv-in-antarctica',
#  '5SH5U3QC': 'Henley Ben, McGregor Helen (2024) 400-year record heat threat to Great Barrier Reef, https://www.bbc.com/news/articles/cy0ngx130kxo',
#  '5TPEAADQ': 'Falster Georgina M., Wright Nicky M., Abram Nerilie J., Ukkola Anna M., Henley Benjamin J. (2024) Potential for historically unprecedented Australian droughts from natural variability and climate change, Hydrology and Earth System Sciences, 28, 1383-1401, DOI:10.5194/hess-28-1383-2024',
#  '5U3PP722': 'Chown S. L. (2024) Macrophysiology: progress and utility.',
#  '6CPV6IMD': "Holden Matthew H., Akinlotan Morenikeji D., Binley Allison D., Cho Frankie H. T., Helmstedt Kate J., Chadès Iadine (2024) Why shouldn't I collect more data? Reconciling disagreements between intuition and value of information analyses, Methods in Ecology and Evolution, 15, 1580-1592, DOI:10.1111/2041-210X.14391",
#  '6MJV2K53': 'Dehling David M. (2024) Ecological Networks',
#  '6MQ6ELVC': 'Svenning Jens-Christian, McGeoch Melodie A., Normand Signe, Ordonez Alejandro, Riede Felix (2024) Navigating ecological novelty towards planetary stewardship: challenges and opportunities in biodiversity dynamics in a transforming biosphere, Philosophical Transactions of the Royal Society B: Biological Sciences, 379, 20230008, DOI:10.1098/rstb.2023.0008',
#  '6PJ6K6PY': 'Patterson C (2024) Predicting Antarctic biodiversity with integrated species distribution models',
#  '6RBB7SDM': 'Parsa Yaryab (2024) Parsayarya/Scraping-ATCM: ATCM WP and IP paper dataset, DOI:10.5281/ZENODO.105788',
#  '6STGMD7P': 'Alinejadtabrizi T., Lang F., Huang Y., Ackermann L., Keywood M., Ayers G., Krummel P., Humphries R., Williams A. G., Siems S. T., Manton M. (2024) Wet deposition in shallow convection over the Southern Ocean, npj Climate and Atmospheric Science, 7, 76, DOI:10.1038/s41612-024-00625-1',
#  '6WVECRQW': 'Leihy R.I., Chown S. L. (2024) Biodiversity knowledge for Antarctic environmental conservation.',
#  '73TDTG2K': 'Purich Ariaan (2024) Unravelling Antarctica’s sea ice puzzle, https://cosmosmagazine.com/earth/oceans/unravelling-antarctica-sea-ice-puzzle/',
#  '74GEEA3L': 'Potapov Anton M., Chen Ting-Wen, Striuchkova Anastasia V., Alatalo Juha M., Alexandre Douglas, Arbea Javier, Ashton Thomas, Ashwood Frank, Babenko Anatoly B., Bandyopadhyaya Ipsa, Baretta Carolina Riviera Duarte Maluche, Baretta Dilmar, Barnes Andrew D., Bellini Bruno C., Bendjaballah Mohamed, Berg Matty P., Bernava Verónica, Bokhorst Stef, Bokova Anna I., Bolger Thomas, Bouchard Mathieu, Brito Roniere A., Buchori Damayanti, Castaño-Meneses Gabriela, Chauvat Matthieu, Chomel Mathilde, Chow Yasuko, Chown Steven L., Classen Aimee T., Cortet Jérôme, Čuchta Peter, De La Pedrosa Ana Manuela, De Lima Estevam C. A., Deharveng Louis E., Doblas Miranda Enrique, Drescher Jochen, Eisenhauer Nico, Ellers Jacintha, Ferlian Olga, Ferreira Susana S. D., Ferreira Aila S., Fiera Cristina, Filser Juliane, Franken Oscar, Fujii Saori, Koudji Essivi Gagnon, Gao Meixiang, Gendreau-Berthiaume Benoit, Gers Charles, Greve Michelle, Hamra-Kroua Salah, Handa I. Tanya, Hasegawa Motohiro, Heiniger Charlène, Hishi Takuo, Holmstrup Martin, Homet Pablo, Høye Toke T., Ivask Mari, Jacques Bob, Janion-Scheepers Charlene, Jochum Malte, Joimel Sophie, Jorge Bruna Claudia S., Juceviča Edite, Kapinga Esther M., Kováč Ľubomír, Krab Eveline J., Krogh Paul Henning, Kuu Annely, Kuznetsova Natalya, Lam Weng Ngai, Lin Dunmei, Lindo Zoë, Liu Amy W. P., Lu Jing-Zhong, Luciáñez María José, Marx Michael T., Mawan Amanda, McCary Matthew A., Minor Maria A., Mitchell Grace I., Moreno David, Nakamori Taizo, Negri Ilaria, Nielsen Uffe N., Ochoa-Hueso Raúl, Oliveira Filho Luís Carlos I., Palacios-Vargas José G., Pollierer Melanie M., Ponge Jean-François, Potapov Mikhail B., Querner Pascal, Rai Bibishan, Raschmanová Natália, Rashid Muhammad Imtiaz, Raymond-Léonard Laura J., Reis Aline S., Ross Giles M., Rousseau Laurent, Russell David J., Saifutdinov Ruslan A., Salmon Sandrine, Santonja Mathieu, Saraeva Anna K., Sayer Emma J., Scheunemann Nicole, Scholz Cornelia, Seeber Julia, Shaw Peter, Shveenkova Yulia B., Slade Eleanor M., Stebaeva Sophya, Sterzynska Maria, Sun Xin, Susanti Winda Ika, Taskaeva Anastasia A., Tay Li Si, Thakur Madhav P., Treasure Anne M, Tsiafouli Maria, Twala Mthokozisi N., Uvarov Alexei V., Venier Lisa A., Widenfalk Lina A., Widyastuti Rahayu, Winck Bruna, Winkler Daniel, Wu Donghui, Xie Zhijing, Yin Rui, Zampaulo Robson A., Zeppelini Douglas, Zhang Bing, Zoughailech Abdelmalek, Ashford Oliver, Klauberg-Filho Osmar, Scheu Stefan (2024) Global fine-resolution data on springtail abundance and community structure, Scientific Data, 11, 22, DOI:10.1038/s41597-023-02784-x',
#  '793YJCZQ': 'Ricci Francesco, Greening Chris (2024) Chemosynthesis: a neglected foundation of marine ecology and biogeochemistry, Trends in Microbiology, 32, 631-639, DOI:10.1016/j.tim.2023.11.013',
#  '7JAY6BF3': 'Deane David C., Hui Cang, McGeoch Melodie (2024) Mean landscape‐scale incidence of species in discrete habitats is patch size dependent, Global Ecology and Biogeography, 33, e13805, DOI:10.1111/geb.13805',
#  '7N9KNCD8': 'Latombe Guillaume, Boittiaux Paul, Hui Cang, McGeoch Melodie A. (2024) A kernel integral method to remove biases in estimating trait turnover, Methods in Ecology and Evolution, 2041-210X.14246, DOI:10.1111/2041-210X.14246',
#  '7QPWGNF3': 'McCormack F. (2024) Geothermal heat flow, subglacial hydrology and East Antarctica’s evolution under climate change',
#  '7Z2IM4A3': 'Zammit-Mangion A (2024) Fast statistical inference with neural networks and amortisation: Golden ticket or red herring? AI for Good',
#  '82Z7VVS3': "Arblaster Julie (2024) Here's what's been pulling the strings on Australia's weather recently — and it's not just El Niño, https://www.abc.net.au/news/2024-01-21/whats-been-driving-australia-climate-recently-weather/103365614",
#  '92J9WGXW': 'Sandino J., Bollard B., Randall K., Barthélemy J, Robinson S., Gonzalez F. (2024) Georeferenced Maps of Moss Health and Lichen in ASPA 135 from multi- and hyperspectral drone Image',
#  '9IV9YIMT': 'Henriksen Marie V., Arlé Eduardo, Pili Arman, Clarke David A., García-Berthou Emili, Groom Quentin, Lenzner Bernd, Meyer Carsten, Seebens Hanno, Tingley Reid, Winter Marten, McGeoch Melodie A. (2024) Global indicators of the environmental impacts of invasive alien species and their information adequacy, Philosophical Transactions of the Royal Society B: Biological Sciences, 379, 20230323, DOI:10.1098/rstb.2023.0323',
#  '9W2URNGW': 'Mills E, Clark G, Simpson M., Baird M., Adams M. (2024) A generalised sigmoid population growth model with energy dependence: application to quantify a tipping point for Antarctic shallow seabed algae',
#  '9W4NUD6U': 'Heidemann Hanna, Cowan Tim, Power Scott B., Henley Benjamin J. (2024) Statistical relationships between the interdecadal Pacific oscillation and el niño–southern oscillation, Climate Dynamics, 62, 2499-2515, DOI:10.1007/s00382-023-07035-8',
#  'A29CADG9': 'North Ryan, Barrows Tim (2024) We used 1,000 historical photos to reconstruct Antarctic glaciers before a dramatic collapse, https://theconversation.com/we-used-1-000-historical-photos-to-reconstruct-antarctic-glaciers-before-a-dramatic-collapse-233972',
#  'ACETER74': 'Robinson S. (2024) The return of the ozone crisis: Why Earth’s atmospheric hole poses a huge threat (again), https://www.sciencefocus.com/nature/ozone-layer-environment',
#  'ADMDJAVR': 'Purich Ariaan (2024) Holes in Ross Sea Ice Grow and Shrink in Unexpected Cycle, https://eos.org/articles/holes-in-ross-sea-ice-grow-and-shrink-in-unexpected-cycle',
#  'AH3C365V': "Strugnell Jan, Lau Sally (2024) Il collasso dell'Antartide occidentale svelato da un polpo, https://www.ilsecoloxix.it/green-and-blue/2024/01/19/news/biodiversita_antartide_polpo-421887301/",
#  'AI5P68XH': "Robinson Sharon, Robinson Sharon (2024) Ozone hole: Why Antarctic wildlife is being 'sunburnt’, https://www.bbc.com/news/science-environment-68906013",
#  'AJ5ES32P': 'Akinlotan Morenikeji D., Warne David J., Helmstedt Kate J., Vollert Sarah A., Chadès Iadine, Heneghan Ryan F., Xiao Hui, Adams Matthew P. (2024) Beyond expected values: Making environmental decisions using value of information analysis when measurement outcome matters, Ecological Indicators, 160, 111828, DOI:10.1016/j.ecolind.2024.111828',
#  'AMDK3GEE': 'Cucchiaro Annalise, Flament Nicolas, Arnould Maëlis, Cressie Noel (2024) Links between large volcanic eruptions, basal mantle structures and mantle plumes',
#  'B2KG4UWT': 'Saunderson Dominic, Mackintosh Andrew N., McCormack Felicity S., Jones Richard S., Van Dalum Christiaan T. (2024) How Does the Southern Annular Mode Control Surface Melt in East Antarctica?, Geophysical Research Letters, 51, e2023GL105475, DOI:10.1029/2023GL105475',
#  'BA2RQJQV': "Lau Sally, Strugnell Jan (2024) Antarctic octopus DNA reveals Earth could be near tipping point: 'A complete collapse could raise global sea levels', https://www.thecooldown.com/green-tech/antarctic-octopus-dna-evidence-breeding-ice-melt/",
#  'BAAKW29N': 'Macha J.M.A., Mackintosh A.N, McCormack F.S., Henley B. J., McGregor H.V., Van Dalum C.T., Purich A. (2024) Distinct Central and Eastern Pacific El Niño Influence on Antarctic Surface Mass Balance, Geophysical Research Letters, 51, e2024GL109423, DOI:10.1029/2024GL109423',
#  'BANG5Q8X': 'Robinson Sharon A., Revell Laura E., Mackenzie Roy, Ossola Rachele (2024) Extended ozone depletion and reduced snow and ice cover—Consequences for Antarctic biota, Global Change Biology, 30, e17283, DOI:10.1111/gcb.17283',
#  'BAZAUGNN': 'Purich Ariaan (2024) Antarctic Sea Ice Alarmingly Low for 3rd Year in a Row, https://www.ecowatch.com/antarctic-sea-ice-low-2024.html',
#  'BWBZBGE6': "Jones Richard (2024) Scientists work to unlock secrets of Antarctica's Denman Glacier, 01 February 2024 , https://www.abc.net.au/listen/programs/pm/scientists-work-to-unlock-secrets-of-antarctica-s-denman-glacier/103416982",
#  'C353XBLD': 'Reid Kimberley J., Arblaster Julie M., Alexander Lisa V., Siems Steven T. (2024) Spurious Trends in High Latitude Southern Hemisphere Precipitation Observations, Geophysical Research Letters, 51, e2023GL106994, DOI:10.1029/2023GL106994',
#  'C3IU44DS': 'Duffy Grant A., Montiel Fabien, Purich Ariaan, Fraser Ceridwen I. (2024) Emerging long-term trends and interdecadal cycles in Antarctic polynyas, Proceedings of the National Academy of Sciences, 121, e2321595121, DOI:10.1073/pnas.2321595121',
#  'C5JF3HPD': 'Lau S.C.Y (2024) What octopus DNA tells us about Antarctic ice sheet collapse?',
#  'C6ZDMNUX': 'Robinson Sharon (2024) Longer-lasting ozone holes over Antarctica expose seal pups and penguin chicks to much more UV, https://www.thehindu.com/sci-tech/science/longer-lasting-ozone-holes-over-antarctica-expose-seal-pups-and-penguin-chicks-to-much-more-uv/article68109257.ece',
#  'CB6AQGWM': 'Jansen Marcel A. K., Andrady Anthony L., Barnes Paul W., Busquets Rosa, Revell Laura E., Bornman Janet F., Aucamp Pieter J., Bais Alkiviadis F., Banaszak Anastazia T., Bernhard Germar H., Bruckman Laura S., Häder Donat‐P., Hanson Mark L., Heikkilä Anu M., Hylander Samuel, Lucas Robyn M., Mackenzie Roy, Madronich Sasha, Neale Patrick J., Neale Rachel E., Olsen Catherine M., Ossola Rachele, Pandey Krishna K., Petropavlovskikh Irina, Robinson Sharon A., Robson T. Matthew, Rose Kevin C., Solomon Keith R., Sulbæk\xa0Andersen Mads P., Sulzberger Barbara, Wallington Timothy J., Wang Qing‐Wei, Wängberg Sten‐Åke, White Christopher C., Young Antony R., Zepp Richard G., Zhu Liping (2024) Environmental plastics in the context of UV radiation, climate change, and the Montreal Protocol, Global Change Biology, 30, e17279, DOI:10.1111/gcb.17279',
#  'CBRJ5QJ4': 'Robinson Sharon (2024) Longer-lasting ozone holes over Antarctica expose seal pups and penguin chicks to much more UV, https://theconversation.com/longer-lasting-ozone-holes-over-antarctica-expose-seal-pups-and-penguin-chicks-to-much-more-uv-227218',
#  'CD5V8VM8': 'Mackintosh A. (2024) More evidence 1.5 degrees exceeded, 12th Novem , https://www.abc.net.au/listen/programs/am/cop-29/104588556',
#  'CEC442BP': 'Lang Francisco, Siems Steven T., Huang Yi, Alinejadtabrizi Tahereh, Ackermann Luis (2024) On the relationship between mesoscale cellular convection and meteorological forcing: comparing the Southern Ocean against the North Pacific, Atmospheric Chemistry and Physics, 24, 1451-1466, DOI:10.5194/acp-24-1451-2024',
#  'CF7HEAY3': 'Chown Steven L., Bastmeijer Kees, Brooks Cassandra M., Gilbert Neil, Phillips Laura M., Shibata Akiho (2024) Science advice for international governance – An evidence-based perspective on the role of SCAR in the Antarctic Treaty System, Marine Policy, 163, 106143, DOI:10.1016/j.marpol.2024.106143',
#  'CKF885QX': "Henley Ben, McGregor Helen (2024) Great Barrier Reef teeters on UNESCO's 'in danger' status after Coral Sea's hottest summer in 400 years, https://www.abc.net.au/news/2024-08-08/coral-sea-hottest-summer-in-400-years-reef-danger/104181382",
#  'CSSF44RS': "Chown Steven, Waterman Melinda, Sandino Juan (2024) Antarctica's miniature moss 'forests' reveal shifts in climate across thousands of years, https://www.abc.net.au/news/science/2024-02-16/science-envt-antarctic-moss-and-climate-change/103431828",
#  'CZ29C72P': 'Purich Ariaan (2024) Out of Sight Out of Mind, https://www.economist.com/interactive/science-and-technology/2024/03/27/antarctica-earths-largest-refrigerator-is-defrosting',
#  'D9NPHRVQ': 'Holland Sophie (2024) Interview with Dr Sophie Holland, 11 February 2024 , https://www.rrr.org.au/explore/programs/einstein-a-go-go/episodes/28179-einstein-a-go-go-11-february-2024',
#  'DDTY97AY': 'Swan M., Galvez J., Travers T. (2024) Team Conducts UAV Research Operations in Remote Antarctica',
#  'DFJ8KKB5': 'Shaw Justine (2024) Islands of hope: The fight to eradicate feral pests and save native wildlife, https://www.smh.com.au/politics/federal/islands-of-hope-the-fight-to-eradicate-feral-pests-and-save-native-wildlife-20240604-p5jj4m.html',
#  'DI35KAUK': 'Purich Ariaan (2024) Antarctica sea ice reaches alarming low for third year in a row, https://www.theguardian.com/world/2024/feb/24/antarctica-sea-ice-reaches-alarming-low-for-third-year-in-a-row',
#  'DITPMNUU': 'Schwindt E., August T. A., Vanderhoeven S., McGeoch M. A., Bacher S., Galil B. S., Genovesi P., Hulme P. E., Ikeda T., Lenzner B., Nuñez M. A., Ordonez A., Pauchard A., Rahlao S. J., Renard Truong T., Roy H. E., Sankaran K. V., Seebens H., Sheppard A. W., Stoett P., Vandvik V., Wilson J. R. U., Meyerson L. A. (2024) Overwhelming evidence galvanizes a global consensus on the need for action against Invasive Alien Species, Biological Invasions, 26, 621-626, DOI:10.1007/s10530-023-03209-x',
#  'DMF3HI63': 'Robinson Sharon (2024) Climate change: Experts are “ringing the bell” for dire consequences in the near future, https://www.thevalleypost.com/climate-change-experts-are-ringing-the-bell-for-dire-consequences-in-the-near-future/',
#  'DU2VZ4P7': 'Chown Steven (2024) The Mouse-Free Marion Project recently hosted two visits by its supporters, https://mousefreemarion.org/the-mouse-free-marion-project-recently-hosted-two-visits-by-its-supporters/',
#  'DWBXQ4GM': 'Travers Toby, Swan Matthew, Galvez Julian (2024) Antarctic exploration, 08 February 2024 , https://www.sbs.com.au/news/video/antarctica-exploration/vk5z1if0e',
#  'DZFVFCQ4': 'Robinson Sharon (2024) Slow pace of Ozone improvement poses threat to Antarctic life, https://cosmosmagazine.com/nature/slow-pace-of-ozone-improvement-poses-threat-to-antarctic-life/',
#  'E2A7JG8Z': 'Jones Richard, Phillips Laura (2024) Could you survive an Antarctic blizzard to look for mud? These scientists had no choice, https://www.theage.com.au/environment/climate-change/could-you-survive-an-antarctic-blizzard-looking-for-mud-these-scientists-had-no-choice-20240207-p5f34g.html',
#  'E7534TV4': 'Lappan Rachael, Thakar Jordan, Moncayo Laura Molares, Besser Alexi, Bradley James A, Goordial Jacqueline, Trembath-Reichert Elizabeth, Greening Chris (2024) The atmosphere: a transport medium or an active microbial ecosystem?, The ISME Journal, wrae092, DOI:10.1093/ismejo/wrae092',
#  'EBG3G5TK': 'Meredith K. (2024) ANSTO submission The Joint Standing Committee on the National Capital and External Territories - Inquiry into the importance of Antarctica to Australia’s national interests',
#  'EC8BW3UC': 'Turnbull John, Johnston Emma, Clark Graeme, Gardner Steph (2024) More than coral: the unseen casualties of record-breaking heat on the Great Barrier Reef, https://theconversation.com/more-than-coral-the-unseen-casualties-of-record-breaking-heat-on-the-great-barrier-reef-227906',
#  'EIPMR62G': 'Robinson Sharon (2024) Antarctica’s Ozone Hole Is Persisting Later Into the Year, Raising Concerns for Wildlife, https://www.smithsonianmag.com/smart-news/antarcticas-ozone-hole-is-persisting-later-into-the-year-raising-concerns-for-wildlife-180984246/',
#  'EQJV4ZFF': 'Shaw J. (2024) Panellist for Careers with STEM',
#  'ET8XA5RX': 'Zheng X. (2024) Spatial-statistical downscaling with uncertainty in Antarctic biodiversity modelling.',
#  'EVMSQHTB': 'Madronich S., Bernhard G. H., Neale P. J., Heikkilä A., Andersen M. P. Sulbæk, Andrady A. L., Aucamp P. J., Bais A. F., Banaszak A. T., Barnes P. J., Bornman J. F., Bruckman L. S., Busquets R., Chiodo G., Häder D.-P., Hanson M. L., Hylander S., Jansen M. A. K., Lingham G., Lucas R. M., Calderon R. Mackenzie, Olsen C., Ossola R., Pandey K. K., Petropavlovskikh I., Revell L. E., Rhodes L. E., Robinson S. A., Robson T. M., Rose K. C., Schikowski T., Solomon K. R., Sulzberger B., Wallington T. J., Wang Q.-W., Wängberg S.-Å., White C. C., Wilson S. R., Zhu L., Neale R. E. (2024) Continuing benefits of the Montreal Protocol and protection of the stratospheric ozone layer for human health and the environment, Photochemical & Photobiological Sciences, 23, 1087-1115, DOI:10.1007/s43630-024-00577-8',
#  'F2W96XUG': 'Selbas J. (2024) Sea-ice Decline—Out of Sight, Out of Mind?, 13 September 2024 , https://arcsaef.com/story/sea-ice-decline-out-of-sight-out-of-mind/',
#  'FGD2AJ2M': 'Galvez-Serna J., Bratanov D. (2024) REF Team operations in Antarctica',
#  'FM4SSLRR': "Meredith K. (2024) ANSTO's commitment to environmental research",
#  'FV7SBSJW': 'Chown Steven (2024) The myths, the politics, and the realities of a warming Antarctica, 07 June 2024 , https://www.2xxfm.org.au/shows/climate-community/',
#  'FYZV9Y9I': 'Sandino J., Swan M., Galvez-Serna J. (2024) Unmanned Aerial Systems Remote Sensing for Vegetation Cover, Health and Drivers\u200b',
#  'G5Y6DPHX': 'Shaw J. (2024) Macquarie Island on the mend after public conservation investment, 21 February 2024 , https://www.abc.net.au/listen/programs/radionational-drive/macquarie-island-conservation-study/103495164',
#  'G62SGZE5': 'Holden Matthew H., Plagányi Eva E., Fulton Elizabeth A., Campbell Alexander B., Janes Rachel, Lovett Robyn A., Wickens Montana, Adams Matthew P., Botelho Larissa Lubiana, Dichmont Catherine M., Erm Philip, Helmstedt Kate J., Heneghan Ryan F., Mendiolar Manuela, Richardson Anthony J., Rogers Jacob G. D., Saunders Kate, Timms Liam (2024) Cost–benefit analysis of ecosystem modeling to support fisheries management, Journal of Fish Biology, 104, 1667-1674, DOI:10.1111/jfb.15741',
#  'G74FU6W9': 'Shaw Justine (2024) Interview with Dr Justine Shaw, 15 March 2024 , https://drive.google.com/file/d/1Kxe_ZPhM5aT1wYOAT_sFWtNxQSZrj-bn/view?usp=drive_link',
#  'G82V8XB7': 'Robinson Sharon (2024) News item, 27 April 2024 , https://drive.google.com/file/d/1eG3Np0spKc7Xiu4D04-cHC-68_gOxvzs/view?usp=drive_link',
#  'GB66JQII': 'Barreto Elisa, Boehm Mannfred M. A., Ogutcen Ezgi, Abrahamczyk Stefan, Kessler Michael, Bascompte Jordi, Dellinger Agnes S., Bello Carolina, Dehling D. Matthias, Duchenne François, Kaehler Miriam, Lagomarsino Laura P., Lohmann Lúcia G., Maglianesi María A., Morlon Hélène, Muchhala Nathan, Ornelas Juan Francisco, Perret Mathieu, Salinas Nelson R., Smith Stacey D., Vamosi Jana C., Varassin Isabela G., Graham Catherine H. (2024) Macroevolution of the plant-hummingbird pollination system, Biological Reviews of the Cambridge Philosophical Society, 99, 1831-1847, DOI:10.1111/brv.13094',
#  'GCPUN6XA': 'Greening Chris, Leung Bob (2024) Some of Earth’s most ancient lifeforms can live on hydrogen – and we can learn from their chemical powers, https://theconversation.com/some-of-earths-most-ancient-lifeforms-can-live-on-hydrogen-and-we-can-learn-from-their-chemical-powers-231382',
#  'GHJLEHVA': 'Bode M. (2024) Mathematics in the Antarctic',
#  'GJ8KCRF5': 'Purich Ariaan (2024) Green Antarctica? Study predicts plants will colonize frigid continent, https://www.conwaydailysun.com/around_the_web/green-antarctica-study-predicts-plants-will-colonize-continent/article_799ed006-3b58-510b-b3e2-9d8c4b43aeb7.html',
#  'GS3YJSW8': 'Gardiner Natasha Blaize, Gilbert Neil, Liggett Daniela, Bode Michael (2024) Measuring the performance of Antarctic Treaty decision‐making, Conservation Biology, e14349, DOI:10.1111/cobi.14349',
#  'GULGW7HQ': 'McCormack F. (2024) Science Meets Parliament. Meeting with Allegra Spender MP, Member for Wentworth.',
#  'GYCUIQRU': "Affleck Saxbee, McGeoch Melodie\xa0A. (2024) Global Avian Functional Diversity Depends on the World's Most Widespread and Distinct Birds, Ecology Letters, 27, e14552, DOI:10.1111/ele.14552",
#  'GYMG4572': 'Patterson C (2024) 25 Rising Stars Women in Data Science',
#  'H3KI3C4M': 'Shaw Justine (2024) Islands of hope: The fight to eradicate feral pests and save native wildlife, https://www.watoday.com.au/politics/federal/islands-of-hope-the-fight-to-eradicate-feral-pests-and-save-native-wildlife-20240604-p5jj4m.html',
#  'H4PBZGNB': 'Robinson Sharon (2024) Ozone hole over Antarctica worst since 1970s, 26 April 2024 , https://www.abc.net.au/listen/programs/pm/ozone-hole-over-antarctica-worst-since-1970s/103774926',
#  'HDKEBJBG': "Robinson Sharon (2024) In Antartide il buco dell'ozono sta danneggiando foche e pinguini, https://www.repubblica.it/green-and-blue/2024/05/07/news/buco_dellozono_antartide_fauna_radiazioni_animali-422835104/",
#  'HKSHAPNC': 'Chown S. L. (2024) Biodiversity informatics for Antarctic environmental conservation',
#  'HL2ZACXU': 'Turner Darren, Cimoli Emiliano, Lucieer Arko, Haynes Ryan S., Randall Krystal, Waterman Melinda J., Lucieer Vanessa, Robinson Sharon A. (2024) Mapping water content in drying Antarctic moss communities using <span style="font-variant:small-caps;">UAS</span> ‐borne <span style="font-variant:small-caps;">SWIR</span> imaging spectroscopy, Remote Sensing in Ecology and Conservation, 10, 296-311, DOI:10.1002/rse2.371',
#  'HM5J76D8': 'Travers Toby, Shaw Justine, Galvez Julian (2024) Drones being used to protect Antarctic biodiversity, https://theqldr.com.au/environmental-issue/2024/02/08/antarctica-3/',
#  'HMW2WJYD': 'Robinson S.A. (2024) Antarctica - The Giant Awakens Q & A [Panel Member}',
#  'HNZ2QBK4': 'Campbell Jillian, Milette Kaite.I, Quesada Marianela, McGeoch Melodie (2024) Webinar: Indicator 6.1 Rate of invasive Alien Species Establishment, June 2024 , https://www.youtube.com/watch?v=WBY6LoeKxtI',
#  'HQ9YAA7P': "Chown S. L., McCormack F., Weller J., Firth, A.  (2024) Antarctica's future is our future",
#  'HWF63UGD': 'Robinson Sharon (2024) Antarctic ozone hole exposes wildlife to harmful UV radiation, https://www.earth.com/news/antarctic-ozone-hole-exposes-wildlife-to-harmful-uv-radiation/',
#  'IFWE2JZC': "Purich A. (2024) Melting of 'doomsday' glacier could mean sea level rise underestimated, 28 May 2024 , https://www.abc.net.au/news/2024-05-28/vigorous-melting-of-doomsday-glacier-could-mean/103900806",
#  'IJYYIT4M': 'Mondol Md Anarul Haque, Zhu Xuan, Dunkerley David, Henley Benjamin J. (2024) Living with technological drought: Experience of smallholding farmers of Bangladesh, Environmental Development, 50, 100985, DOI:10.1016/j.envdev.2024.100985',
#  'IUU97XUZ': 'Waterman Melinda (2024) Interview with Dr Melinda Waterman, 28 February 2024 , https://drive.google.com/file/d/1zzMKlQsHdOJ6DCy0Iq-iYh0JjaZqQewF/view?usp=drive_link',
#  'IXSX9R57': 'Alinejadtabrizi Tahereh, Siems Steven (2024) The Southern Ocean has the cleanest air on Earth. We have just discovered why, https://theconversation.com/the-southern-ocean-has-the-cleanest-air-on-earth-we-have-just-discovered-why-226811',
#  'J7RAMU4D': 'Purich Ariaan (2024) Green Antarctica? Study predicts plants will colonize frigid continent, https://www.nbcrightnow.com/national/green-antarctica-study-predicts-plants-will-colonize-frigid-continent/article_2d9e677d-6621-5b69-82d2-108e20cd907a.html',
#  'J9EHHY28': 'Jones R. (2024) Understanding ice sheet retreat using subglacial drilling.',
#  'JB6KPAGN': 'Chown Steven, Purich Ariaan (2024) Australia and New Zealand Antarctic Leaders Meet to Discuss Collaborative Research Priorities, https://tribune-intl.com/australian-and-new-zealand-antarctic-leaders-meet-to-discuss-collaborative-research-priorities/',
#  'JBAVIF8E': 'Onley Isabelle R., Houghton Melissa J., Leggett Kirsten, Cassey Phill, Carter Zachary T., Shaw Justine (2024) Assessing ongoing risks and managing detections of non-native invertebrates in the Antarctic Region, NeoBiota, 95, 133-147, DOI:10.3897/neobiota.95.124706',
#  'JDR6KU43': 'Purich Ariaan (2024) Was This Really a 1 in 700,000,000,000 Year Event?! - Antarctic sea ice melting fast, 28 February 2024 , https://www.youtube.com/watch?v=eGkJSEOd1R4',
#  'JFHT2C9T': 'Nuñez Martin A., August Tom, Bacher Sven, Galil Bella S., Hulme Philip E., Ikeda Tohru, McGeoch Melodie A., Ordonez Alejandro, Rahlao Sebataolo, Truong Tanara Renard, Pauchard Aníbal, Roy Helen E., Sankaran K.V., Schwindt Evangelina, Seebens Hanno, Sheppard Andy W., Stoett Peter, Vandvik Vigdis, Meyerson Laura A. (2024) Including a diverse set of voices to address biological invasions, Trends in Ecology & Evolution, 39, 409-412, DOI:10.1016/j.tree.2024.02.009',
#  'JG3AXJLJ': 'Henley B (2024) Recent Coral Sea and Great Barrier Reef surface temperatures in a multi-century context',
#  'JVCJ8X6V': "O'Connor Jacinda (2024) Interview with Jacinda O'Connor, 15 February 2024 , https://www.abc.net.au/listen/programs/melbourne-afternoons/afternoons/103449146",
#  'JVH2F966': 'Robinson Sharon (2024) Antarctic Wildlife Faces Increased UV Exposure as Ozone Hole Expands, https://www.onegreenplanet.org/animals/antarctic-wildlife-faces-increased-uv-exposure-as-ozone-hole-expands/',
#  'K2QPD9KY': 'Varliero Gilda, Lebre Pedro H., Adams Byron, Chown Steven L., Convey Peter, Dennis Paul G., Fan Dandan, Ferrari Belinda, Frey Beat, Hogg Ian D., Hopkins David W., Kong Weidong, Makhalanyane Thulani, Matcher Gwynneth, Newsham Kevin K., Stevens Mark I., Weigh Katherine V., Cowan Don A. (2024) Biogeographic survey of soil bacterial communities across Antarctica, Microbiome, 12, 9, DOI:10.1186/s40168-023-01719-3',
#  'K3UR8XVG': 'Tielidze Levan, O\'Connor Jacinda, Jones Richard, Port Corey (2024) ანტარქტიდა "გლობალური დათბობა და ქართველი მეცნიერი" - დოკუმენტური ფილმი, 28 April 2024 , https://www.youtube.com/watch?v=uj4TO0NdnnU&t=190s',
#  'K74FVFV8': 'Robinson S. (2024) UN Environment Programme International Day of Women and Girls in Science 2024',
#  'K7WBWCFY': 'Chown S.L. (2024) Scotch college Oration - title TBC',
#  'LBTTE837': 'Stoeckl Natalie, Adams Vanessa, Baird Rachel, Boothroyd Anne, Costanza Robert, Hatton MacDonald Darla, Finau Glenn, Fulton Elizabeth A., King Matt A., Kubiszewski Ida, Lannuzel Delphine, Leane Elizabeth, Melbourne-Thomas Jess, Neilsen Hanne, Ooi Can-Seng, Raghavan Mala, Senigaglia Valeria, Tian Jing, Yamazaki Satoshi (2024) Publisher Correction: The value of Antarctic and Southern Ocean ecosystem services, Nature Reviews Earth & Environment, 5, 226-226, DOI:10.1038/s43017-024-00535-z',
#  'LLDRRG65': 'Parsa Yaryab (2024) Parsayarya/ATS-Measure-Scraping: ATS Measure Dataset, DOI:10.5281/ZENODO.105787',
#  'LSHMW3CL': 'Deng Y.N., Roberts S.J., Saunders K.M., Perrens B (2024) Late Holocene lake ecosystem change and the Southern Hemisphere Westerlies on sub-Antarctic Macquarie Island. EGU24-1508.',
#  'LVJWFPSC': 'McNeil M (2024) Sights and Soundings from the Shackleton Ice Shelf, Antarctica.',
#  'LY5U9IEW': 'Henley Benjamin J., McGregor Helen V., King Andrew D., Hoegh-Guldberg Ove, Arzey Ariella K., Karoly David J., Lough Janice M., DeCarlo Thomas M., Linsley Braddock K. (2024) Highest ocean heat in four centuries places Great Barrier Reef in danger, Nature, 632, 320-326, DOI:10.1038/s41586-024-07672-x',
#  'LZE7K4WS': 'Buba Yehezkel, Kiflawi Moshe, McGeoch Melodie A., Belmaker Jonathan (2024) Evaluating models for estimating introduction rates of alien species from discovery records, Global Ecology and Biogeography, e13859, DOI:10.1111/geb.13859',
#  'M2HNB3G2': 'Robinson Sharon (2024) Women in Science, https://ozone.unep.org/sharon-robinson',
#  'M4H95QW3': 'Purich Ariaan (2024) Unravelling Antarctica’s sea ice puzzle, https://360info.org/unravelling-antarcticas-sea-ice-puzzle/',
#  'MI9L7DV2': 'Martins Lucas P., Stouffer Daniel B., Blendinger Pedro G., Böhning-Gaese Katrin, Costa José Miguel, Dehling D. Matthias, Donatti Camila I., Emer Carine, Galetti Mauro, Heleno Ruben, Menezes Ícaro, Morante-Filho José Carlos, Muñoz Marcia C., Neuschulz Eike Lena, Pizo Marco Aurélio, Quitián Marta, Ruggera Roman A., Saavedra Francisco, Santillán Vinicio, Schleuning Matthias, Da Silva Luís Pascoal, Ribeiro Da Silva Fernanda, Tobias Joseph A., Traveset Anna, Vollstädt Maximilian G. R., Tylianakis Jason M. (2024) Birds optimize fruit size consumed near their geographic range limits, Science, 385, 331-336, DOI:10.1126/science.adj1856',
#  'MKI28DRD': 'Jones Richard (2024) Interview with Richard Jones, 05 February 2024 , https://drive.google.com/file/d/1EPFuvJZku8PWVswkVCS2rlVELbCFpCH8/view?usp=drive_link',
#  'MLUGHMK9': 'Terauds A., Wauchope H.S, Wen W, Lee J. R. (2024) Antarctic Specially Protected Areas (Points and Polygons) 2024 Update, DOI:http://dx.doi.org/doi:10.26179/4qk0-cz',
#  'MQBWRNTW': 'Robinson Sharon (2024) News item, 26 April 2024 , https://drive.google.com/file/d/1fSGz8XmFiR-nYF3bAbLRcNRN5bzXozjO/view?usp=drive_link',
#  'MU2SVAZD': 'D’Olivo Juan P., Zinke Jens, Goyal Rishav, England Matthew H., Purich Ariaan, Corrège Thierry, Zorita Eduardo, Scholz Denis, Weber Michael, Carriquiry José D. (2024) Coral Sr/Ca-SST reconstruction from Fiji extending to ~1370 CE reveals insights into the Interdecadal Pacific Oscillation, Science Advances, 10, eado5107, DOI:10.1126/sciadv.ado5107',
#  'N4U9TKVL': 'Henley B (2024) Reconstructions and model simulations of regional sea surface temperatures place recent Great Barrier Reef temperatures into a multi-century context',
#  'N6X7FT27': 'Smith J. (2024) Australia in Antarctica. Invited lecture to participants in the Defence and Strategic Studies Course',
#  'NXFPW4LI': 'Henley Ben, McGregor Helen (2024) Heat raises fears of "demise" for Great Barrier Reef within a generation, https://www.nytimes.com/2024/08/07/climate/ocean-heat-great-barrier-reef.html',
#  'P926ZSRE': 'Strugnell Jan, Lau Sally, Wilson Nerida (2024) Interview with Cat Williams, 09 February 2024 , https://drive.google.com/file/d/1h_oixNXoaM8kq8eamFksiBuWO5-WIsVk/view?usp=drive_link',
#  'PPW95S9Z': 'North Ryan, Barrows Timothy T. (2024) High-resolution elevation models of Larsen B glaciers extracted from 1960s imagery, Scientific Reports, 14, 14536, DOI:10.1038/s41598-024-65081-6',
#  'PRE4ELR4': 'Robinson Sharon (2024) Researchers hope to monitor Antarctic vegetation remotely, https://cosmosmagazine.com/nature/can-we-monitor-the-antarctic-remotely/',
#  'Q2YMU4FD': 'Pertierra Luis, Varliero Gilda, Barbosa Andrés, Biersma Elisabeth, Convey Peter, Chown Steven, Cowan Don, De Los Rios Asunción, Escribano-Alvarez Pablo, Fontaneto Diego, Fraser Ceridwen, Harris Mathew, Hughes Kevin, Griffiths Huw, Le Roux Peter, Liu Xiaoyue, Lynch Heather, Majewska Roksana, Martinez Pablo, Molina-Montenegro Marco, Olalla-Tarraga Miguel, Peck Lloyd, Quesada Antonio, Ronquillo Cristina, Ropert-Coudert Yan, Sancho Leopoldo, Terauds Aleks, Vianna Juliana, Wilmotte Annick, Hortal Joaquín, Greve Michelle (2024) TerrANTALife 1.0 Biodiversity data checklist of known Antarctic terrestrial and freshwater life forms, Biodiversity Data Journal, 12, e106199, DOI:10.3897/BDJ.12.e106199',
#  'Q89U2FQ8': 'McCormack Felicity (2024) Geothermal Heat Shapes the Antarctic Ice Sheet From Below, https://kids.frontiersin.org/articles/10.3389/frym.2023.1178537',
#  'QMP3F6FV': 'Jones Richard, Phillips Laura (2024) Could you survive an Antarctic blizzard to look for mud? These scientists had no choice, https://www.smh.com.au/environment/climate-change/could-you-survive-an-antarctic-blizzard-looking-for-mud-these-scientists-had-no-choice-20240207-p5f34g.html',
#  'QR2SHL5P': 'Lee J. (2024) Exhibit in the 1851der tent',
#  'QTCX8BU7': "Purich Ariaan (2024) Unravelling Antarctica's sea ice puzzle, https://www.theweek.in/news/sci-tech/2024/01/22/unravelling-antarctica-s-sea-ice-puzzle.html",
#  'QUFVSBIV': 'Raniga Damini, Sandino Juan, Bollard Barbara, Randall Krystal, Barthelemy Johan, Robinson Sharon A., Gonzalez Felipe (2024) Multispectral Georeferenced Maps of Moss Health and Lichen in ASPA 135 using Drones and ',
#  'QWW45SER': 'Cressie N. (2024) A strategy for statistical analysis of safety samples',
#  'R23YW89U': 'Krastel S, Barrett R, Baumann L, Cornish N, Gohl K, Hochmuth K, Höppner L, Klages J, Krause T, McNeil M, Schwarzbach P, Tobisch C, Weigelt E (2024) Glaciomorphological features on the East Antarctic Davis and Mawson Sea continental shelves - First results from Polarstern Expedition PS141',
#  'R5VTKSIZ': 'Robinson Sharon (2024) News item, 26 April 2024 , https://drive.google.com/file/d/1z9n09G-VXhbaTylAHcfIyePGerX6bG1d/view?usp=drive_link',
#  'R8CG7FKN': 'Greening Chris, Cabotaje Princess R., Valentin Alvarado Luis E., Leung Pok Man, Land Henrik, Rodrigues-Oliveira Thiago, Ponce-Toledo Rafael I., Senger Moritz, Klamke Max A., Milton Michael, Lappan Rachael, Mullen Susan, West-Roberts Jacob, Mao Jie, Song Jiangning, Schoelmerich Marie, Stairs Courtney W., Schleper Christa, Grinter Rhys, Spang Anja, Banfield Jillian F., Berggren Gustav (2024) Minimal and hybrid hydrogenases are active from archaea, Cell, 187, 3357-3372.e19, DOI:10.1016/j.cell.2024.05.032',
#  'R8V35J76': 'Wilson Nerida (2024) Octopus DNA predicts future of West Antarctic Ice Sheet, 18 January 2024 ',
#  'RHAEREFI': 'Helmstedt K., Shaw J. (2024) Queensland University of Technology submission to the Joint Standing Committee on the National Capital and External Territories inquiry into the importance of Antarctica to Australia’s national interests Submission',
#  'RNDWFCU8': 'Robinson Sharon (2024) De ce încă riscă animalele din Antarctica să facă „insolație”: Gaura din stratul de ozon persistă deasupra continentului înghețat, avertizează oamenii de știință, https://www.g4media.ro/de-ce-inca-risca-animalele-din-antarctica-sa-faca-insolatie-gaura-din-stratul-de-ozon-persista-deasupra-continentului-inghetat-avertizeaza-oamenii-de-stiinta.html',
#  'RSNG9SE8': "Purich Ariaan (2024) Antarctica's sea ice drops to an 'alarming low' for the third year in a row, scientists warn, https://www.dailymail.co.uk/sciencetech/article-13126187/Antarcticas-sea-ice-drops-alarming-low.html",
#  'S32E3EJQ': 'Macha J. (2024) El Nino influence on West Antarctic snow accumulation, 01 September 2024 , https://www.rrr.org.au/explore/programs/einstein-a-go-go/episodes/30624-einstein-a-go-go-1-september-2024',
#  'S3MC6WWE': 'Wilson Nerida, Strugnell Jan, Lau Sally (2024) Scientists date Antarctic ice collapse',
#  'S68JXHGM': 'Robinson Sharon (2024) Interview with Distinguished Professor Sharon Robinson, 30 April 2024 , https://drive.google.com/file/d/1FHwv3oZVEWEktGVe5pk6cYGk5Le6PUft/view?usp=drive_link',
#  'S8VP3FJX': 'Lee Jasmine R., Shaw Justine D., Ropert-Coudert Yan, Terauds Aleks, Chown Steven L. (2024) Conservation features of the terrestrial Antarctic Peninsula, Ambio, DOI:10.1007/s13280-024-02009-4',
#  'SBTTMN9W': 'Jones Richard (2024) Denman Terrestrial Campaign Enters Final Weeks After Blue Skies, Blizzards and Long Days on the Ice, https://www.antarctica.gov.au/news/2024/denman-terrestrial-campaign-update/',
#  'SF4WTACE': 'De Oliveira Anderson Rodolfo (2024) Continent-wide analysis of moss diversity in Antarctica, DOI:10.26180/24456994.',
#  'SK83Z89C': 'Purich Ariaan (2024) Unravelling Antarctica’s Shrinking Sea Ice Levels, https://science.thewire.in/environment/unravelling-antarcticas-shrinking-sea-ice-levels/',
#  'SM327465': 'Travers Toby, Shaw Justine, Galvez Julian (2024) Drones being used to protect Antarctic biodiversity, https://thewest.com.au/technology/drones-being-used-to-protect-antarctic-biodiversity-c-13514359?utm_source=csp&utm_medium=portal&utm_campaign=Meltwater&token=JL3y2jsvHBi5fFskpMQvyJWpdo7z%2BWw5b2IonmR0o%2BRF%2ByZBejPGA4E8fQKNkHvjysJAXrFmlyk4US7b8BGKWQ%3D%3D',
#  'SMRRQXAM': 'Robinson Sharon (2024) Hole in the ozone layer causing Antarctic wildlife to being sunburnt, https://www.dailymail.co.uk/galleries/article-13362569/Hole-ozone-layer-causing-Antarctic-wildlife-sunburnt.html',
#  'SQPDF7AX': 'McGeoch M. A. (2024) Bridging monitoring and decision support for range expanding species.',
#  'TCUUKE59': 'Robinson S. (2024) International Women’s Day Q&A Panel',
#  'TKVESIGZ': 'Robinson Sharon (2024) Sunburnt seals and penguins? Antarctica’s ozone layer the worst it’s been since 1970s, https://www.stuff.co.nz/climate-change/350258857/sunburnt-seals-and-penguins-antarcticas-ozone-layer-worst-its-been-1970s',
#  'TPYIYRHH': 'Sandino J., Amarasingam N., Galvez-Serna J., Swan M., Gonzalez F. (2024) High-Tech For Low Temperature: Monitoring Antarctic Vegetation From Above Using Drones and AI [Pull-up Banner]. Securing Antarctica’s Environmental Future (SAEF)',
#  'TTUXWKV3': 'Mackintosh A., McCormack F., Jones R., Purich A., Beckmann J., Tielidze L., Saunderson D., Macha J., Rand C., Bird L., Strugnell J., Lau S.C.Y, Smith J., McNeill M, Zammit-Mangion A, Henley B, McGregor H., SAEF Theme 1 Ice Sheets Team  (2024) Securing Antarctica’s Environmental Future: the East Antarctic Ice Sheet',
#  'U2WATG69': "Henley Ben, McGregor Helen (2024) 'Wake-up call to humanity’: research shows the Great Barrier Reef is the hottest it’s been in 400 years, https://theconversation.com/wake-up-call-to-humanity-research-shows-the-great-barrier-reef-is-the-hottest-its-been-in-400-years-235876",
#  'UAZEDB5C': "Robinson Sharon (20240928) The hole in the ozone Layer was late this year. It's not good news",
#  'UI5JEATV': 'Robinson Sharon (2024) Sunburnt seals and penguins? Antarctica’s ozone layer the worst it’s been since 1970s, https://www.smh.com.au/environment/climate-change/sunburnt-seals-and-penguins-antarctica-s-ozone-layer-the-worst-it-s-been-since-1970s-20240423-p5fm32.html',
#  'UK74JMIR': 'Robinson Sharon (2024) Interview with Sharon Robinson, 27 April 2024 , https://mms.tveyes.com/mediaview/?...',
#  'ULADXJFN': 'Gardner Steph, Turnbull John (2024) A beautifil disaster, https://www.australiangeographic.com.au/topics/science-environment/2024/07/a-beautiful-disaster/',
#  'UTFCXZC6': 'Ficetola Gentile Francesco, Marta Silvio, Guerrieri Alessia, Cantera Isabel, Bonin Aurélie, Cauvy-Fraunié Sophie, Ambrosini Roberto, Caccianiga Marco, Anthelme Fabien, Azzoni Roberto Sergio, Almond Peter, Alviz Gazitúa Pablo, Ceballos Lievano Jorge Luis, Chand Pritam, Chand Sharma Milap, Clague John J., Cochachín Rapre Justiniano Alejo, Compostella Chiara, Encarnación Rolando Cruz, Dangles Olivier, Deline Philip, Eger Andre, Erokhin Sergey, Franzetti Andrea, Gielly Ludovic, Gili Fabrizio, Gobbi Mauro, Hågvar Sigmund, Kaufmann Rüdiger, Khedim Norine, Meneses Rosa Isela, Morales-Martínez Marco Aurelio, Peyre Gwendolyn, Pittino Francesca, Proietto Angela, Rabatel Antoine, Sieron Katrin, Tielidze Levan, Urseitova Nurai, Yang Yan, Zaginaev Vitalii, Zerboni Andrea, Zimmer Anaïs, Diolaiuti Guglielmina Adele, Taberlet Pierre, Poulenard Jerome, Fontaneto Diego, Thuiller Wilfried, Carteron Alexis (2024) The development of terrestrial ecosystems emerging after glacier retreat, Nature, DOI:10.1038/s41586-024-07778-2',
#  'V2SV3MZ4': 'Galvez-Serna J., Swan M. (2024) QUT Bold Ideas',
#  'V93AVT2V': 'Lyons J. (2024) Sensors in Antarctica',
#  'VC9ZET49': 'Strugnell Jan, Lau Sally, Wilson Nerida (2024) Octopus DNA is key for scientists to better predict climate change, https://www.thesaturdaypaper.com.au/share/17690/2yVhKGRw',
#  'VNA47C8A': 'Robinson Sharon (2024) Is The Hole In The Ozone Layer Giving Antarctic Animals “Sunburn”?, https://www.iflscience.com/is-the-hole-in-the-ozone-layer-giving-antarctic-animals-sunburn-74062',
#  'VPATGH7Z': 'Chown Steven (2024) Antarctica Under Threat, https://particle.scitech.org.au/people/antarctica-under-threat/',
#  'VQ4Y23IA': 'Purich Ariaan (2024) A 600-year-old coral shows us how the Pacific Ocean has changed since 1370, https://theconversation.com/a-600-year-old-coral-shows-us-how-the-pacific-ocean-has-changed-since-1370-236740',
#  'VT6CM64K': 'Roy Helen E., Pauchard Aníbal, Stoett Peter J., Renard Truong Tanara, Meyerson Laura A., Bacher Sven, Galil Bella S., Hulme Philip E., Ikeda Tohru, Kavileveettil Sankaran, McGeoch Melodie A., Nuñez Martin A., Ordonez Alejandro, Rahlao Sebataolo J., Schwindt Evangelina, Seebens Hanno, Sheppard Andy W., Vandvik Vigdis, Aleksanyan Alla, Ansong Michael, August Tom, Blanchard Ryan, Brugnoli Ernesto, Bukombe John K., Bwalya Bridget, Byun Chaeho, Camacho-Cervantes Morelia, Cassey Phillip, Castillo María L., Courchamp Franck, Dehnen-Schmutz Katharina, Zenni Rafael Dudeque, Egawa Chika, Essl Franz, Fayvush Georgi, Fernandez Romina D., Fernandez Miguel, Foxcroft Llewellyn C., Genovesi Piero, Groom Quentin J., González Ana Isabel, Helm Aveliina, Herrera Ileana, Hiremath Ankila J., Howard Patricia L., Hui Cang, Ikegami Makihiko, Keskin Emre, Koyama Asuka, Ksenofontov Stanislav, Lenzner Bernd, Lipinskaya Tatsiana, Lockwood Julie L., Mangwa Dongang C., Martinou Angeliki F., McDermott Shana M., Morales Carolina L., Müllerová Jana, Mungi Ninad Avinash, Munishi Linus K., Ojaveer Henn, Pagad Shyama N., Pallewatta Nirmalie P. K. T. S., Peacock Lora R., Per Esra, Pergl Jan, Preda Cristina, Pyšek Petr, Rai Rajesh K., Ricciardi Anthony, Richardson David M., Riley Sophie, Rono Betty J., Ryan-Colton Ellen, Saeedi Hanieh, Shrestha Bharat B., Simberloff Daniel, Tawake Alifereti, Tricarico Elena, Vanderhoeven Sonia, Vicente Joana, Vilà Montserrat, Wanzala Wycliffe, Werenkraut Victoria, Weyl Olaf L. F., Wilson John R. U., Xavier Rafael O., Ziller Sílvia R. (2024) Curbing the major and growing threats from invasive alien species is urgent and achievable, Nature Ecology & Evolution, DOI:10.1038/s41559-024-02412-w',
#  'W7RLGGP2': 'Roland Thomas P., Bartlett Oliver T., Charman Dan J., Anderson Karen, Hodgson Dominic A., Amesbury Matthew J., Maclean Ilya, Fretwell Peter T., Fleming Andrew (2024) Sustained greening of the Antarctic Peninsula observed from satellites, Nature Geoscience, DOI:10.1038/s41561-024-01564-5',
#  'WCXI6JJA': 'Debnath Dipraj, Vanegas Fernando, Sandino Juan, Hawary Ahmad Faizul, Gonzalez Felipe (2024) A Review of UAV Path-Planning Algorithms and Obstacle Avoidance Methods for Remote Sensing Applications, Remote Sensing, 16, 4019, DOI:10.3390/rs16214019',
#  'WDD67AHL': 'Raniga Damini, Amarasingam Narmilan, Sandino Juan, Doshi Ashray, Barthelemy Johan, Randall Krystal, Robinson Sharon A., Gonzalez Felipe, Bollard Barbara (2024) Monitoring of Antarctica’s Fragile Vegetation Using Drone-Based Remote Sensing, Multispectral Imagery and AI, Sensors, 24, 1063, DOI:10.3390/s24041063',
#  'WDLPAVAS': 'Kanranth S. (2024) Usage of k-means clustering for defining Macquarie Island’s ecosystems and their collapses.',
#  'WG229VTX': 'Robinson Sharon (2024) News item, 27 April 2024 , https://drive.google.com/file/d/1Fp6znL8aTlTOPZBVcHk2bLJAYUTP3WxS/view?usp=drive_link',
#  'WG78S2W3': 'Robinson S. (2024) The return of the ozone crisis: Why Earth’s atmospheric hole poses a huge threat (again), https://cosmosmagazine.com/nature/slow-pace-of-ozone-improvement-poses-threat-to-antarctic-life/',
#  'WGLE6UEA': 'Chown Steven (2024) Should Antarctica be off limits?, 18 July 2024 , https://www.bbc.co.uk/sounds/play/m002137z',
#  'WHAUN76W': 'Cassey P. (2024) Cutting-edge technology is being deployed to stop the illegal trafficking of Australian wildlife, July 2024 , https://www.abc.net.au/news/2024-07-08/cutting-edge-technology-to-stop-wildlife-trafficking/104030746',
#  'WLNF6Y32': 'Jones Richard S., Miller Lauren E., Westoby Matthew J. (2024) How can geomorphology facilitate a better understanding of glacier and ice sheet behaviour?, Earth Surface Processes and Landforms, esp.5932, DOI:10.1002/esp.5932',
#  'WVP7WYXY': 'Henley Ben, McGregor Helen (2024) Last summer was so hot on the Great Barrier Reef, even the scientist didn’t believe it, https://www.theage.com.au/environment/climate-change/last-summer-was-so-hot-on-the-great-barrier-reef-even-the-scientist-didn-t-believe-it-20240807-p5k099.html',
#  'WWIAI7C9': 'Robinson Sharon (2024) Interview with Sharon Robinson, 27 April 2024 , https://mms.tveyes.com/mediaview/?...',
#  'X2PYDYHP': 'Galvez-Serna J. (2024) Casey Talks',
#  'XAHDECKI': 'Robinson Sharon (2024) Sunburnt seals and penguins? Antarctica’s ozone layer the worst it’s been since 1970s, https://www.theage.com.au/environment/climate-change/sunburnt-seals-and-penguins-antarctica-s-ozone-layer-the-worst-it-s-been-since-1970s-20240423-p5fm32.html',
#  'XUB66R34': 'Cressie N. (2024) WOMBAT: Bayesian inference on carbon-dioxide surface fluxes from satellite data',
#  'YR97LH7Y': "Lim Eun-Pa, Lim Eun-Pa (2024) Record 50C temperature increase over Antarctica to shift Australia's weather patterns, https://www.abc.net.au/news/2024-07-27/nsw-antarctica-warming-over-50c/104142332?utm_campaign=abc_news_web&utm_content=link&utm_medium=content_shared&utm_source=abc_news_web",
#  'YT3VMU5I': 'McGeoch M. A. (2024) Old gaps and new solutions for global biodiversity monitoring and decision-support.',
#  'YWK6GIJN': 'Zammit-Mangion A. (2024) Bayesian neural networks for spatial process modelling',
#  'Z6WD7VET': 'Williams K (2024) MCIF Grants',
#  'Z9RQWD4M': 'Purich Ariaan (2024) Inside Antarctica’s sea ice puzzle, https://newsroom.co.nz/2024/01/23/unravelling-antarcticas-sea-ice-puzzle/',
#  'ZA76YZIZ': 'Vu Bao Anh, Gunawan David, Zammit-Mangion Andrew (2024) R-VGAL: a sequential variational Bayes algorithm for generalised linear mixed models, Statistics and Computing, 34, 110, DOI:10.1007/s11222-024-10422-8',
#  'ZQNXFG5S': 'Alinejadtabrizi Tahereh, Siems Steven (2024) Honeycomb clouds give the Southern Ocean the Earth’s sweetest air, https://www.australiangeographic.com.au/news/2024/04/southern-ocean-cleanest-air/',
#  'ZR72CMMS': 'Tielidze Levan (2024) From microbes to mammals: we tracked the rapid rise of new ecosystems as glaciers retreat and ice sheets melt, https://theconversation.com/from-microbes-to-mammals-we-tracked-the-rapid-rise-of-new-ecosystems-as-glaciers-retreat-and-ice-sheets-melt-235687',
#  'ZS3TR6C6': 'Cressie N. (2024) Spatial prediction of non-negative spatial process using asymmetric loss functions',
#  'ZWYMTVS4': 'Pelle T., Greenbaum J. S., Ehrenfeucht S., Dow C. F., McCormack F. S. (2024) Subglacial Discharge Accelerates Dynamic Retreat of Aurora Subglacial Basin Outlet Glaciers, East Antarctica, Over the 21st Century, Journal of Geophysical Research: Earth Surface, 129, e2023JF007513, DOI:10.1029/2023JF007513',
#  'ZZSBNS9X': "O'Connor Jacinda (2024) Interview with Jacinda O'Connor, 18 February 2024 , https://www.rrr.org.au/explore/programs/einstein-a-go-go/episodes/28267-einstein-a-go-go-18-february-2024"}

# %%
# Out:
# McGeoch Melodie A., Clarke David A., Mungi Ninad Avinash, Ordonez Alejandro

# %%
'one' in x
# Out:
# True
